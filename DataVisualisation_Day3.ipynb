# %% [markdown]
# <a href="https://colab.research.google.com/github/shankarbalaji124/DataVisualisation_Day3/blob/main/DataVisualisation_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset('fmri')
data
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x='timepoint', y = 'signal',data = data,hue = 'event')

# %%
sns.lineplot(x='signal',y = 'region',data = data,size = 'subject')

# %%
sns.boxplot(x='subject',y ='timepoint',hue ='region',data = data )

# %%
sns.catplot(x= 'signal',y = 'subject',kind = 'violin',data = data)
